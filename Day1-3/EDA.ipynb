# %% [markdown]
# - Load 2 csvs
# - Clean data
# - Save as 2 cleaned csvs
# - as py file (executable)

# %%
import pandas as pd

# %%
books = pd.read_csv('C:\\Users\\Admin\\Desktop\\DE5-M5\\data\\03_Library Systembook.csv')
display(books)
# Out:
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# ..   ...                                       ...           ...
# 109  NaN                                       NaN           NaN
# 110  NaN                                       NaN           NaN
# 111  NaN                                       NaN           NaN
# 112  NaN                                       NaN           NaN
# 113  NaN                                       NaN           NaN
#
#     Book Returned Days allowed to borrow  Customer ID
# 0      25/02/2023                2 weeks          1.0
# 1      21/03/2023                2 weeks          2.0
# ...

# %%
customers = pd.read_csv('C:\\Users\\Admin\\Desktop\\DE5-M5\\data\\03_Library SystemCustomers.csv')
display(customers)
# Out:
#    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 3          NaN               NaN
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted

# %%
#Drop null rows
customers = customers.dropna()
books = books.dropna()

display(customers)
display(books)
# Out:
#    Customer ID     Customer Name
# 0          1.0          Jane Doe
# 1          2.0        John Smith
# 2          3.0        Dan Reeves
# 4          5.0    William Holden
# 5          6.0     Jaztyn Forest
# 6          7.0     Jackie Irving
# 7          8.0  Matthew Stirling
# 8          9.0         Emory Ted
#       Id                                     Books Book checkout  \
# 0    1.0                       Catcher in the Rye   "20/02/2023"
# 1    2.0          Lord of the rings the two towers  "24/03/2023"
# 2    3.0  Lord of the rings the return of the kind  "29/03/2023"
# 3    4.0                                The hobbit  "02/04/2023"
# 4    5.0                                     Dune   "02/04/2023"
# 5    6.0                              Little Women  "02/04/2023"
# 6    7.0                                        IT  "10/04/2063"
# 7    8.0                                   Misery   "15/04/2023"
# 8    9.0                                  Catch 22  "15/04/2023"
# ...

# %%
#Data types
print(books.dtypes)
print(customers.dtypes)
# Out:
# Id                        float64
# Books                      object
# Book checkout              object
# Book Returned              object
# Days allowed to borrow     object
# Customer ID               float64
# dtype: object
# Customer ID      float64
# Customer Name     object
# dtype: object

# %%
#Formatting data
books['Books'] = books['Books'].str.title()
books["Book checkout"] = books["Book checkout"].str.replace('"','')
books.columns = books.columns.str.title()
display (books)
# Out:
#       Id                                     Books Book Checkout  \
# 0    1.0                       Catcher In The Rye     20/02/2023
# 1    2.0          Lord Of The Rings The Two Towers    24/03/2023
# 2    3.0  Lord Of The Rings The Return Of The Kind    29/03/2023
# 3    4.0                                The Hobbit    02/04/2023
# 4    5.0                                     Dune     02/04/2023
# 5    6.0                              Little Women    02/04/2023
# 6    7.0                                        It    10/04/2063
# 7    8.0                                   Misery     15/04/2023
# 8    9.0                                  Catch 22    15/04/2023
# 9   10.0                              Animal Farm     20/04/2023
# 10  11.0                                      1984    23/04/2023
# 11  12.0                              Little Women    02/04/2023
# 12  13.0                              East Of Eden    30/04/2023
# ...
